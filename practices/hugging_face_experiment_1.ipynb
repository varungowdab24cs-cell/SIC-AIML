# %%
from transformers import pipeline

# %%
pip install ipywidgets
# Out:
# ...
#
# ...
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#   Using cached webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# ...
# Using cached webcolors-25.10.0-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# ...

# %%
model=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
model("Today is hectic")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9918380379676819}]

# %%
dir(pipeline)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']

# %%
#Task:"Zero-shot-classification"

# %%
model = pipeline('zero-shot-classification')
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
model("This is a training program on Artificial Intelligence", candidate_labels=["sports","education","academics","politics"])
# Out:
# {'sequence': 'This is a training program on Artificial Intelligence',
#  'labels': ['education', 'academics', 'sports', 'politics'],
#  'scores': [0.6514576077461243,
#   0.18451130390167236,
#   0.1034756675362587,
#   0.06055545061826706]}

# %%
LM = "HuggingFaceTB/SmolLM2-135M-Instruct"

# %%
model = pipeline('text-generation',model=LM)
# Out:
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# C:\Users\SIC\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\SIC\.cache\huggingface\hub\models--HuggingFaceTB--SmolLM2-135M-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
text=model("gravity")

# %%
text
# Out:
# [{'generated_text': "gravity of a particular object. We can create a map of the world where the object is placed. This can be done using a library that provides a way to map objects and their properties.\n\nWe can then iterate over the objects in the world and find the object with the minimum number of iterations to reach the target world-node. We can do this by recursively calling our function with the object's ID, the target world-node, and the number of iterations to reach the target world-node.\n\nHere's how we can implement this in Python:\n\n```python\nimport heapq\n\ndef find_target_world_node(object_id, target_world_node, iterations):\n    for obj, _ in object_id.items():\n        if not heapq.heappush(heapq.heap_ring(obj), -1) and iterations > 0:\n            target_world_node = target_world_node - obj\n            return target_world_node\n    return -1\n```\n\nThis implementation uses a heap to keep track of the objects to be visited. It recursively calls itself with the o
# ...

# %%
print(text[0]["generated_text"])
# Out:
# gravity of a particular object. We can create a map of the world where the object is placed. This can be done using a library that provides a way to map objects and their properties.
#
# We can then iterate over the objects in the world and find the object with the minimum number of iterations to reach the target world-node. We can do this by recursively calling our function with the object's ID, the target world-node, and the number of iterations to reach the target world-node.
#
# Here's how we can implement this in Python:
#
# ```python
# import heapq
#
# def find_target_world_node(object_id, target_world_node, iterations):
#     for obj, _ in object_id.items():
#         if not heapq.heappush(heapq.heap_ring(obj), -1) and iterations > 0:
#             target_world_node = target_world_node - obj
#             return target_world_node
#     return -1
# ```
#
# ...

# %%
image_classifier=pipeline('image-classification',model="google/vit-base-patch16-224")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\SIC\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\SIC\.cache\huggingface\hub\models--google--vit-base-patch16-224. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
image_classifier(r"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcR293INgAdmAcl9wAQSzHuhxhRmkmDpUnRxof1uQ8psRA&s=10")
# Out:
# [{'label': 'comic book', 'score': 0.9036111235618591},
#  {'label': 'book jacket, dust cover, dust jacket, dust wrapper',
#   'score': 0.0708099827170372},
#  {'label': 'breastplate, aegis, egis', 'score': 0.007275066338479519},
#  {'label': 'shield, buckler', 'score': 0.005457059480249882},
#  {'label': 'cuirass', 'score': 0.00215362012386322}]
